# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanyresque/projeto-IBM/blob/main/projeto_IBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %%
import pandas as pd

BASE = 'employee_attrition.csv'

df = pd.read_csv(BASE)

# %% [markdown]
# # Checagem básica

# %% [markdown]
# - shape
# - colunas
# - tipos
# - valores nulos
# - valores "estranhos"
# - valores únicos
# - valores duplicados
# - contagem de valores relevantes

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
with pd.option_context('display.max_columns', 35):
  display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
with pd.option_context('float_format', '{:.2f}'.format,'display.max_columns', 35):
  display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
df.describe(exclude = 'number')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# OBS.: *O dataset é desbalanceado, ou seja, a quantidade de funcionários que saíram da empresa é muito menor que a quantidade de funcionários que permaneceram na empresa. Isso pode influenciar na análise dos dados.*
#
# A coluna "Attrition" é a coluna que indica se o funcionário saiu da empresa ou não. Ela é a chama coluna alvo, ou target. Esse nome é dado pois é a coluna que queremos avaliar e prever.

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.select_dtypes('object').nunique()
# Out:
# Attrition         2
# BusinessTravel    3
# Department        3
# EducationField    6
# Gender            2
# JobRole           9
# MaritalStatus     3
# Over18            1
# OverTime          2
# dtype: int64

# %%
df.select_dtypes('object')
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
df.select_dtypes('number')
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %% [markdown]
# ## Buscando outliers

# %% [markdown]
# **Explicando quartis e outliers**
#
# Quartis são valores que dividem um conjunto de dados em quatro partes iguais. O primeiro quartil (Q1) é o valor que deixa 25% dos dados abaixo e 75% acima. O segundo quartil (Q2) é a mediana, que deixa 50% dos dados abaixo e 50% acima. O terceiro quartil (Q3) deixa 75% dos dados abaixo e 25% acima.
#
# Por exemplo, se temos um conjunto de dados com 100 valores, o primeiro quartil (Q1) será o valor que deixa 25 valores abaixo e 75 acima. O segundo quartil (Q2) será o valor que deixa 50 valores abaixo e 50 acima. O terceiro quartil (Q3) será o valor que deixa 75 valores abaixo e 25 acima.
#
# Outliers são valores que fogem do padrão do conjunto de dados. São valores muito altos ou muito baixos que podem influenciar negativamente na análise dos dados. Por exemplo, se temos um conjunto de dados com salários de funcionários de uma empresa, e um dos salários é muito maior que os outros, esse salário pode ser considerado um outlier.
#
# Estatisticamente, um outlier é um valor que está a mais de 1,5 vezes o intervalo interquartil acima do terceiro quartil (Q3) ou a mais de 1,5 vezes o intervalo interquartil abaixo do primeiro quartil (Q1). O intervalo interquartil é a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1).

# %%
with pd.option_context('float_format', '{:.2f}'.format,'display.max_columns', 35):
  display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
1.5 * (43 - 30) #intervalo interquatil -> para idade!
# Out:
# 19.5

# %%
30 - 1.5 * (43 - 30) #qualquer valor abaixo de 10.5 seria considerado um outlier para menos
# Out:
# 10.5

# %%
43 + 1.5 * (43 - 30) #qualquer valor acima de 62.5 seria considerado um outlier para mais
# Out:
# 62.5

# %%
#para DistanceFromHome

1.5 * (14 - 2)
# Out:
# 18.0

# %%
2 - 1.5 * (14 - 2)
# Out:
# -16.0

# %%
14 + 1.5 * (14 - 2)
#tbm não temos outliers
# Out:
# 32.0

# %%
#para TotalWorkingYears

1.5 * (15 - 6)
# Out:
# 13.5

# %%
6 - 1.5 * (15 - 6)
# Out:
# -7.5

# %%
15 + 1.5 * (15 - 6)
#temos um outlier
# Out:
# 28.5

# %%
#MonthlyIncome	MonthlyRate

1.5 * (8379-2911)
# Out:
# 8202.0

# %%
2911 - 1.5 * (8379-2911)
# Out:
# -5291.0

# %%
8379 +1.5 * (8379-2911)
#tbm há outlier
# Out:
# 16581.0

# %%
1.5 * (20461 - 8047)
# Out:
# 18621.0

# %%
8047 - 1.5 * (20461 - 8047)
# Out:
# -10574.0

# %%
20461 + 1.5 * (20461 - 8047)
# Out:
# 39082.0

# %% [markdown]
# # Primeiras alterações

# %%
with pd.option_context('display.max_columns', 35):
  display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#EmployeeCount, Over18, StandardHours

df = df.drop(['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber'], axis=1) #axis para mostrar que é um eixo de coluna a ser removido

# %%
with pd.option_context('display.max_columns', 35):
  display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %%
with pd.option_context('float_format', '{:.2f}'.format,'display.max_columns', 35):
  display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  \
# count 1470.00    1470.00           1470.00    1470.00
# mean    36.92     802.49              9.19       2.91
# std      9.14     403.51              8.11       1.02
# min     18.00     102.00              1.00       1.00
# 25%     30.00     465.00              2.00       2.00
# 50%     36.00     802.00              7.00       3.00
# 75%     43.00    1157.00             14.00       4.00
# max     60.00    1499.00             29.00       5.00
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# count                  1470.00     1470.00         1470.00   1470.00
# mean                      2.72       65.89            2.73      2.06
# std                       1.09       20.33            0.71      1.11
# min                       1.00       30.00            1.00      1.00
# 25%                       2.00       48.00            2.00      1.00
# ...

# %%
# df[df['Age'] > df['Age'].median()].sort_values(by = 'Age').tail(10)

df.nlargest(10, 'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# ...

# %%
# df[df['Age'] <= df['Age'].median()].sort_values(by = 'Age').head(10)

df.nsmallest(10, 'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# ...

# %%
# df[df['YearsAtCompany'] > df['YearsAtCompany'].median()].sort_values(by = 'YearsAtCompany').tail(10)

df.nlargest(10, 'YearsAtCompany')
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 126                 23          4           Medical                        4
# ...

# %%
# df[df['YearsAtCompany'] <= df['YearsAtCompany'].median()].sort_values(by = 'YearsAtCompany').head(10)

df.nsmallest(10, 'YearsAtCompany')
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 23    21        No      Travel_Rarely        391  Research & Development
# 77    45        No      Travel_Rarely        193  Research & Development
# 86    23        No      Travel_Rarely        541                   Sales
# 109   22        No      Travel_Rarely        534  Research & Development
# 127   19       Yes      Travel_Rarely        528                   Sales
# 171   19       Yes  Travel_Frequently        602                   Sales
# 264   28       Yes      Travel_Rarely        529  Research & Development
# 265   29        No      Travel_Rarely       1210                   Sales
# 296   18       Yes      Travel_Rarely        230  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 2                   2          2             Other                        4
# ...

# %%
# df[df['YearsSinceLastPromotion'] > df['YearsSinceLastPromotion'].median()].sort_values(by = 'YearsSinceLastPromotion').tail(10)

df.nlargest(10, 'YearsSinceLastPromotion')
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# ...

# %%
df.nlargest(10, 'YearsSinceLastPromotion')[['Age','JobRole','Department','YearsSinceLastPromotion','JobLevel']]
# Out:
#      Age                    JobRole              Department  \
# 45    41          Research Director  Research & Development
# 123   51          Research Director  Research & Development
# 126   58  Healthcare Representative  Research & Development
# 178   46            Sales Executive                   Sales
# 237   52                    Manager                   Sales
# 425   50                    Manager  Research & Development
# 701   53                    Manager                   Sales
# 752   36      Laboratory Technician  Research & Development
# 861   46                    Manager                   Sales
# 914   55  Healthcare Representative  Research & Development
#
#      YearsSinceLastPromotion  JobLevel
# 45                        15         5
# 123                       15         5
# 126                       15         3
# 178                       15         3
# 237                       15         5
# 425                       15         4
# ...

# %%
# df[df['YearsSinceLastPromotion'] <= df['YearsSinceLastPromotion'].median()].sort_values(by = 'YearsSinceLastPromotion').head(10)

df.nsmallest(10, 'YearsSinceLastPromotion')
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 6    59        No  Travel_Rarely       1324  Research & Development
# 7    30        No  Travel_Rarely       1358  Research & Development
# 10   35        No  Travel_Rarely        809  Research & Development
# 11   29        No  Travel_Rarely        153  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 16   32        No  Travel_Rarely        334  Research & Development
# 17   22        No     Non-Travel       1123  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
#
#     DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                  1          2  Life Sciences                        2
# 2                  2          2          Other                        4
# ...

# %%
df.nsmallest(10, 'YearsSinceLastPromotion')[['Age','JobRole','Department','YearsSinceLastPromotion','JobLevel']]
# Out:
#     Age                JobRole              Department  \
# 0    41        Sales Executive                   Sales
# 2    37  Laboratory Technician  Research & Development
# 6    59  Laboratory Technician  Research & Development
# 7    30  Laboratory Technician  Research & Development
# 10   35  Laboratory Technician  Research & Development
# 11   29  Laboratory Technician  Research & Development
# 14   28  Laboratory Technician  Research & Development
# 16   32     Research Scientist  Research & Development
# 17   22  Laboratory Technician  Research & Development
# 21   36   Sales Representative                   Sales
#
#     YearsSinceLastPromotion  JobLevel
# 0                         0         2
# 2                         0         1
# 6                         0         1
# 7                         0         1
# 10                        0         1
# 11                        0         2
# 14                        0         1
# 16                        0         1
# ...

# %% [markdown]
# # Agrupamentos

# %% [markdown]
# OBS: normalmente usamos atributos com poucos valores únicos e que apresentam ordem para fazermos agrupamentos.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
colunas_categoricas_nao_ordenadas = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime'
]

colunas_categoricas_ordenadas = [
    'Education',
    'EnvironmentSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'JobSatisfaction',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance'
]

coluna_alvo = ['Attrition']

colunas_numericas = [
    coluna for coluna in df.columns if coluna not in (
      colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas + coluna_alvo
    )
]

# %%
colunas_numericas
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for coluna in (colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas):
  print(f'{coluna}: {df[coluna].unique()}')
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
# Education: [2 1 4 3 5]
# EnvironmentSatisfaction: [2 3 4 1]
# JobInvolvement: [3 2 4 1]
# JobLevel: [2 1 3 4 5]
# JobSatisfaction: [4 2 3 1]
# PerformanceRating: [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel: [0 1 3 2]
# WorkLifeBalance: [1 3 2 4]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
for coluna in colunas_categoricas_nao_ordenadas:
  df[coluna] = df[coluna].astype('category') #dizer para o pandas que é categórico

# %%
df.info() #repare que o uso de memória diminui
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
df['OverTime'].cat.categories
# Out:
# Index(['No', 'Yes'], dtype='object')

# %%
df['OverTime'].cat.ordered
# Out:
# False

# %%
df['OverTime']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
df['OverTime'].cat.codes
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    1
# 1468    0
# 1469    0
# Length: 1470, dtype: int8

# %%
for coluna in df.select_dtypes(include = 'category'):
  print(f"{coluna}")
  print(f"{coluna}.cat.categories: {df[coluna].cat.categories}")
  print(f"{coluna}.cat.ordered: {df[coluna].cat.ordered}")
  print(f"{coluna}.cat.codes: {df[coluna].cat.codes.unique()}")
  print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
# ...

# %%
with pd.option_context('display.max_columns', 35):
  display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %%
df['Attrition'].value_counts().plot(kind = 'bar');

# %%
df['Attrition'].value_counts().plot(kind = 'bar', color = ['blue', 'red']);

# %%
df['Department'].value_counts().plot(kind = 'bar');

# %%
df.groupby(['Department', 'Attrition']).size()
# Out:
# <ipython-input-60-b1539732e323>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Department', 'Attrition']).size()
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
df.pivot_table(
    index = 'Department',
    columns = 'Attrition',
    aggfunc = 'size'
)
# Out:
# <ipython-input-61-3fdd3652a6a3>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(df['Department'], df['Attrition'])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(df['Department'], df['Attrition'], normalize='index') #de todos os funcionários do departamento x quantos saíram?
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
pd.crosstab(df['Department'], df['Attrition'], normalize='index').style.background_gradient(cmap = 'RdYlGn', axis = 1)
# Out:
# <style type="text/css">
# #T_a09d6_row0_col0, #T_a09d6_row1_col0, #T_a09d6_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a09d6_row0_col1, #T_a09d6_row1_col1, #T_a09d6_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a09d6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_a09d6_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a09d6_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a09d6_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_a09d6_row0_col0" class="data row0 col0" >0.809524</td>
#       <td id="T_a09d6_row0_col1" class="data row0 col1" >0.190476</td>
# ...

# %%
pd.crosstab(df['Department'], df['Attrition'], normalize='columns') #de todos os funcionários que saíram, quantos são do departamento x?
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.041363  0.050633
# Research & Development  0.671533  0.561181
# Sales                   0.287105  0.388186

# %%
pd.crosstab(df['Department'], df['Attrition'], margins = True, margins_name = 'Total')
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %%
pd.crosstab(df['Department'], df['Attrition']).plot(kind = 'bar');

# %%
df.groupby(['Department'])['MonthlyIncome'].mean()
# Out:
# <ipython-input-68-d47e0ee61879>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Department'])['MonthlyIncome'].mean()
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby(['Department'])['MonthlyIncome'].mean().plot(kind = 'bar');
# Out:
# <ipython-input-69-6bfc7880d134>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Department'])['MonthlyIncome'].mean().plot(kind = 'bar');

# %%
df.groupby(['Department', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# <ipython-input-70-35b73a2bfe01>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Department', 'Attrition'])['MonthlyIncome'].mean()
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %%
df.pivot_table(
    index = 'Department',
    columns = 'Attrition',
    values = 'MonthlyIncome',
    aggfunc = 'mean'
).style.background_gradient(cmap = 'RdYlGn', axis = 1)
# Out:
# <ipython-input-71-db8d9a5a4586>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# <style type="text/css">
# #T_61d1a_row0_col0, #T_61d1a_row1_col0, #T_61d1a_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_61d1a_row0_col1, #T_61d1a_row1_col1, #T_61d1a_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61d1a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_61d1a_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_61d1a_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
# ...

# %%
df.pivot_table(
    index = 'Department',
    columns = 'Attrition',
    values = 'MonthlyIncome',
    aggfunc = 'mean'
).plot(kind = 'bar');
# Out:
# <ipython-input-72-e18f10317657>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(

# %%
df.groupby(['JobRole'])['MonthlyIncome'].mean()
# Out:
# <ipython-input-73-0e0f272074ed>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole'])['MonthlyIncome'].mean()
# JobRole
# Healthcare Representative     7528.763359
# Human Resources               4235.750000
# Laboratory Technician         3237.169884
# Manager                      17181.676471
# Manufacturing Director        7295.137931
# Research Director            16033.550000
# Research Scientist            3239.972603
# Sales Executive               6924.279141
# Sales Representative          2626.000000
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean()
# Out:
# <ipython-input-74-ca6107c240d8>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean()
# JobRole                    JobLevel
# Healthcare Representative  1                    NaN
#                            2            5865.346154
#                            3            9363.954545
#                            4           12973.000000
#                            5                    NaN
# Human Resources            1            2733.212121
#                            2            5563.461538
#                            3            9623.000000
#                            4                    NaN
#                            5                    NaN
# Laboratory Technician      1            2854.590000
# ...

# %%
df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame().style.background_gradient(cmap = 'RdYlGn', axis = 0)
# Out:
# <ipython-input-75-b7d296a61b04>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame().style.background_gradient(cmap = 'RdYlGn', axis = 0)
# <style type="text/css">
# #T_60f87_row0_col0, #T_60f87_row4_col0, #T_60f87_row8_col0, #T_60f87_row9_col0, #T_60f87_row13_col0, #T_60f87_row14_col0, #T_60f87_row15_col0, #T_60f87_row16_col0, #T_60f87_row20_col0, #T_60f87_row24_col0, #T_60f87_row25_col0, #T_60f87_row26_col0, #T_60f87_row33_col0, #T_60f87_row34_col0, #T_60f87_row35_col0, #T_60f87_row39_col0, #T_60f87_row42_col0, #T_60f87_row43_col0, #T_60f87_row44_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_60f87_row1_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_60f87_row2_col0 {
# ...

# %%
df.groupby(['JobRole', 'JobLevel','Attrition'])['MonthlyIncome'].mean()
# Out:
# <ipython-input-76-6bd2e6cbdc3f>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel','Attrition'])['MonthlyIncome'].mean()
# JobRole                    JobLevel  Attrition
# Healthcare Representative  1         No                   NaN
#                                      Yes                  NaN
#                            2         No           5828.280000
#                                      Yes          6792.000000
#                            3         No           9426.282051
#                                                      ...
# Sales Representative       3         Yes                  NaN
#                            4         No                   NaN
#                                      Yes                  NaN
# ...

# %%
df.pivot_table(
    index = ['JobRole', 'JobLevel'],
    columns = 'Attrition',
    values = 'MonthlyIncome',
    aggfunc = 'mean'
).style.background_gradient(cmap = 'RdYlGn', axis = 1)
# Out:
# <ipython-input-77-4710fb9e63cd>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# <style type="text/css">
# #T_a28f0_row0_col0, #T_a28f0_row1_col1, #T_a28f0_row2_col1, #T_a28f0_row3_col1, #T_a28f0_row4_col0, #T_a28f0_row4_col1, #T_a28f0_row5_col0, #T_a28f0_row6_col1, #T_a28f0_row7_col0, #T_a28f0_row8_col1, #T_a28f0_row9_col0, #T_a28f0_row10_col0, #T_a28f0_row10_col1, #T_a28f0_row11_col0, #T_a28f0_row12_col1, #T_a28f0_row13_col0, #T_a28f0_row14_col0, #T_a28f0_row14_col1, #T_a28f0_row15_col0, #T_a28f0_row15_col1, #T_a28f0_row16_col0, #T_a28f0_row16_col1, #T_a28f0_row17_col0, #T_a28f0_row18_col1, #T_a28f0_row19_col1, #T_a28f0_row20_col0, #T_a28f0_row20_col1, #T_a28f0_row21_col0, #T_a28f0_row22_col0, #T_a28f0_row23_col0, #T_a28f0_row24_col1, #T_a28f0_row25_col1 {
#   background-color: #a50026;
# ...

# %%
df.pivot_table(
    index = ['JobRole', 'JobLevel'],
    columns = 'Attrition',
    values = 'MonthlyIncome',
    aggfunc = ['mean', 'size']
) #isso nos ajuda a pensar na possibilidade de outliers e/ou situações de excessões
# Out:
# <ipython-input-78-e65793300e9e>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# <ipython-input-78-e65793300e9e>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
df.pivot_table(
    index = ['JobRole', 'JobLevel'],
    columns = 'Attrition',
    values = 'MonthlyIncome',
    aggfunc = ['mean', 'size']
).dropna(how='all', subset=[('mean', 'No'),('mean', 'Yes')])
# Out:
# <ipython-input-79-b504fd959510>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# <ipython-input-79-b504fd959510>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
df.pivot_table(
    index = ['JobRole', 'JobLevel'],
    columns = 'Attrition',
    values = 'MonthlyIncome',
    aggfunc = ['size']
)
# Out:
# <ipython-input-80-0d9d82e66615>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                    size
# Attrition                            No Yes
# JobRole                   JobLevel
# Healthcare Representative 1           0   0
#                           2          75   3
#                           3          39   5
#                           4           8   1
#                           5           0   0
# Human Resources           1          23  10
#                           2          13   0
#                           3           4   2
#                           4           0   0
#                           5           0   0
# Laboratory Technician     1         144  56
#                           2          51   5
#                           3           2   1
# ...

# %%
pd.crosstab([df['JobRole'], df['JobLevel']], df['Attrition'])
# Out:
# Attrition                            No  Yes
# JobRole                   JobLevel
# Healthcare Representative 2          75    3
#                           3          39    5
#                           4           8    1
# Human Resources           1          23   10
#                           2          13    0
#                           3           4    2
# Laboratory Technician     1         144   56
#                           2          51    5
#                           3           2    1
# Manager                   3          10    2
#                           4          47    0
#                           5          40    3
# Manufacturing Director    2          85    5
#                           3          40    5
#                           4          10    0
# Research Director         3          28    0
#                           4          26    0
#                           5          24    2
# Research Scientist        1         189   45
# ...

# %%
pd.crosstab(
    [df['JobRole'], df['JobLevel']],
    df['Attrition'],
    normalize = 'index'
).style.background_gradient(cmap = 'RdYlGn', axis = 1, vmin=0, vmax = 1)
# Out:
# <style type="text/css">
# #T_78dcf_row0_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_78dcf_row0_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_78dcf_row1_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_78dcf_row1_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_78dcf_row2_col0, #T_78dcf_row13_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_78dcf_row2_col1, #T_78dcf_row13_col1 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_78dcf_row3_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_78dcf_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_78dcf_row4_col0, #T_78dcf_row10_col0, #T_78dcf_row14_col0, #T_78dcf_row15_col0, #T_78dcf_row16_col0, #T_78dcf_row20_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# ...

# %%
pd.crosstab(
    df['Department'],
    df['Gender'],
    margins=True,
    margins_name='Total'
)
# Out:
# Gender                  Female  Male  Total
# Department
# Human Resources             20    43     63
# Research & Development     379   582    961
# Sales                      189   257    446
# Total                      588   882   1470

# %%
df.pivot_table(
    index = ['Department', 'Gender'],
    columns = 'Attrition',
    aggfunc = 'size'
)
# Out:
# <ipython-input-84-146013063aa5>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# Attrition                       No  Yes
# Department             Gender
# Human Resources        Female   14    6
#                        Male     37    6
# Research & Development Female  336   43
#                        Male    492   90
# Sales                  Female  151   38
#                        Male    203   54

# %%
pd.crosstab(
    df['JobRole'],
    df['Gender'],
    margins=True,
    margins_name='Total'
)
# Out:
# Gender                     Female  Male  Total
# JobRole
# Healthcare Representative      51    80    131
# Human Resources                16    36     52
# Laboratory Technician          85   174    259
# Manager                        47    55    102
# Manufacturing Director         72    73    145
# Research Director              33    47     80
# Research Scientist            114   178    292
# Sales Executive               132   194    326
# Sales Representative           38    45     83
# Total                         588   882   1470

# %%
df.pivot_table(
    index = ['JobRole', 'Gender'],
    columns = 'Attrition',
    aggfunc = 'size'
)
# Out:
# <ipython-input-86-5598a9a1aa48>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# Attrition                          No  Yes
# JobRole                   Gender
# Healthcare Representative Female   46    5
#                           Male     76    4
# Human Resources           Female   10    6
#                           Male     30    6
# Laboratory Technician     Female   69   16
#                           Male    128   46
# Manager                   Female   45    2
#                           Male     52    3
# Manufacturing Director    Female   68    4
#                           Male     67    6
# Research Director         Female   32    1
#                           Male     46    1
# Research Scientist        Female   97   17
#                           Male    148   30
# ...

# %%
df.groupby('Education')['MonthlyIncome'].mean()
# Out:
# Education
# 1    5640.570588
# 2    6226.645390
# 3    6517.263986
# 4    6832.402010
# 5    8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
mapeamento_educacao = {
    1: 'Below college',
    2: 'College',
    3: 'Bachelor',
    4: 'Master',
    5: 'PhD'
}

# %%
df.groupby('Education')['MonthlyIncome'].mean().rename(index=mapeamento_educacao)
# Out:
# Education
# Below college    5640.570588
# College          6226.645390
# Bachelor         6517.263986
# Master           6832.402010
# PhD              8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('Education').size().rename(index=mapeamento_educacao)
# Out:
# Education
# Below college    170
# College          282
# Bachelor         572
# Master           398
# PhD               48
# dtype: int64

# %%
df.groupby(['Education', 'Attrition']).size().rename(index=mapeamento_educacao)
# Out:
# Education      Attrition
# Below college  No           139
#                Yes           31
# College        No           238
#                Yes           44
# Bachelor       No           473
#                Yes           99
# Master         No           340
#                Yes           58
# PhD            No            43
#                Yes            5
# dtype: int64

# %%
pd.crosstab(df['Education'], df['Attrition'], margins = True, margins_name = 'Total').rename(index=mapeamento_educacao)
# Out:
# Attrition        No  Yes  Total
# Education
# Below college   139   31    170
# College         238   44    282
# Bachelor        473   99    572
# Master          340   58    398
# PhD              43    5     48
# Total          1233  237   1470

# %%
pd.crosstab(
    df['Education'],
    df['Attrition'],
    margins = True,
    margins_name = 'Total',
    normalize = 'index'
).rename(index=mapeamento_educacao)
# Out:
# Attrition            No       Yes
# Education
# Below college  0.817647  0.182353
# College        0.843972  0.156028
# Bachelor       0.826923  0.173077
# Master         0.854271  0.145729
# PhD            0.895833  0.104167
# Total          0.838776  0.161224

# %%
pd.crosstab(
    df['Education'],
    df['Attrition'],
    margins = True,
    margins_name = 'Total',
    normalize = 'columns'
).rename(index=mapeamento_educacao)
# Out:
# Attrition            No       Yes     Total
# Education
# Below college  0.112733  0.130802  0.115646
# College        0.193025  0.185654  0.191837
# Bachelor       0.383617  0.417722  0.389116
# Master         0.275750  0.244726  0.270748
# PhD            0.034874  0.021097  0.032653

# %%
pd.crosstab(
    df['Education'],
    df['Department'],
    margins = True,
    margins_name = 'Total',

).rename(index=mapeamento_educacao)
# Out:
# Department     Human Resources  Research & Development  Sales  Total
# Education
# Below college                5                     115     50    170
# College                     13                     182     87    282
# Bachelor                    27                     379    166    572
# Master                      15                     255    128    398
# PhD                          3                      30     15     48
# Total                       63                     961    446   1470

# %%
pd.crosstab(
    df['Education'],
    df['JobRole'],
    margins = True,
    margins_name = 'Total',

).rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below college                         15                5
# College                               21               12
# Bachelor                              48               22
# Master                                44               10
# PhD                                    3                3
# Total                                131               52
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below college                     35        9                      15
# College                           57       19                      33
# Bachelor                         104       40                      54
# Master                            58       29                      38
# PhD                                5        5                       5
# Total                            259      102                     145
#
# ...

# %%
pd.crosstab(
    df['Education'],
    df['JobRole'],
    margins = True,
    margins_name = 'Total',
    normalize = 'index'
).rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below college                   0.088235         0.029412
# College                         0.074468         0.042553
# Bachelor                        0.083916         0.038462
# Master                          0.110553         0.025126
# PhD                             0.062500         0.062500
# Total                           0.089116         0.035374
#
# JobRole        Laboratory Technician   Manager  Manufacturing Director  \
# Education
# Below college               0.205882  0.052941                0.088235
# College                     0.202128  0.067376                0.117021
# Bachelor                    0.181818  0.069930                0.094406
# Master                      0.145729  0.072864                0.095477
# PhD                         0.104167  0.104167                0.104167
# Total                       0.176190  0.069388                0.098639
#
# ...

# %%
pd.crosstab(
    df['Education'],
    df['JobRole'],
    margins = True,
    margins_name = 'Total',
    normalize = 'columns'
).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below college                      11.45             9.62
# College                            16.03            23.08
# Bachelor                           36.64            42.31
# Master                             33.59            19.23
# PhD                                 2.29             5.77
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below college                  13.51     8.82                   10.34
# College                        22.01    18.63                   22.76
# Bachelor                       40.15    39.22                   37.24
# Master                         22.39    28.43                   26.21
# PhD                             1.93     4.90                    3.45
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below college               8.75               12.67             8.28
# ...

# %%
pd.crosstab(
    df['Education'],
    df['JobLevel'],
    margins = True,
    margins_name = 'Total',
    normalize = 'index',
).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4     5
# Education
# Below college  52.35  27.65  11.76   4.71  3.53
# College        33.33  44.33  11.70   6.03  4.61
# Bachelor       40.38  29.90  17.13   7.69  4.90
# Master         30.40  42.96  14.57   7.04  5.03
# PhD            16.67  41.67  18.75  18.75  4.17
# Total          36.94  36.33  14.83   7.21  4.69

# %%
pd.crosstab(
    df['Education'],
    df['JobLevel'],
    margins = True,
    margins_name = 'Total',
    normalize = 'columns',
).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4      5  Total
# Education
# Below college  16.39   8.80   9.17   7.55   8.70  11.56
# College        17.31  23.41  15.14  16.04  18.84  19.18
# Bachelor       42.54  32.02  44.95  41.51  40.58  38.91
# Master         22.28  32.02  26.61  26.42  28.99  27.07
# PhD             1.47   3.75   4.13   8.49   2.90   3.27

# %%
pd.crosstab(
    [df['JobRole'], df['Education']],
    df['JobLevel'],
    margins = True,
    margins_name = 'Total',
).rename(index=mapeamento_educacao)
# Out:
# JobLevel                                   1    2    3    4   5  Total
# JobRole                   Education
# Healthcare Representative Below college    0    8    5    2   0     15
#                           College          0   15    4    2   0     21
#                           Bachelor         0   25   20    3   0     48
#                           Master           0   28   15    1   0     44
#                           PhD              0    2    0    1   0      3
# Human Resources           Below college    4    1    0    0   0      5
#                           College          9    2    1    0   0     12
#                           Bachelor        13    6    3    0   0     22
#                           Master           6    2    2    0   0     10
#                           PhD              1    2    0    0   0      3
# Laboratory Technician     Below college   32    3    0    0   0     35
#                           College         39   16    2    0   0     57
# ...

# %%
pd.crosstab(
    [df['JobRole'], df['JobLevel'], df['Attrition']],
    df['Education'],
    margins = True,
    margins_name = 'Total',
).rename(columns=mapeamento_educacao)
# Out:
# Education                                     Below college  College  \
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No                     7       13
#                                    Yes                    1        2
#                           3        No                     4        3
#                                    Yes                    1        1
#                           4        No                     2        2
#                                    Yes                    0        0
# Human Resources           1        No                     3        7
#                                    Yes                    1        2
#                           2        No                     1        2
#                           3        No                     0        0
#                                    Yes                    0        1
# Laboratory Technician     1        No                    24       30
# ...

# %% [markdown]
# # Gráficos para visualização

# %%
df.groupby('Gender').size()
# Out:
# <ipython-input-103-a179ec220ebb>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender').size()
# Gender
# Female    588
# Male      882
# dtype: int64

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# <ipython-input-104-2e5120796486>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Age'].mean()
# Gender
# Female    37.329932
# Male      36.653061
# Name: Age, dtype: float64

# %%
df.groupby('Gender')['Age'].value_counts()
# Out:
# <ipython-input-105-12542d4ded39>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Age'].value_counts()
# Gender  Age
# Female  34     33
#         29     29
#         36     29
#         31     28
#         35     27
#                ..
# Male    18      4
#         57      4
#         59      4
#         54      3
#         60      3
# Name: count, Length: 86, dtype: int64

# %%
df.groupby('Gender')['Age'].value_counts(bins = 10)
# Out:
# <ipython-input-106-f33c35b9b3ef>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Age'].value_counts(bins = 10)
# Gender  Age
# Female  (34.8, 39.0]                  117
#         (30.6, 34.8]                  108
#         (26.4, 30.6]                   89
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (51.6, 55.8]                   36
#         (47.4, 51.6]                   35
#         (22.2, 26.4]                   32
#         (17.956999999999997, 22.2]     25
#         (55.8, 60.0]                   21
# Male    (34.8, 39.0]                  180
#         (30.6, 34.8]                  157
#         (26.4, 30.6]                  135
#         (39.0, 43.2]                  106
# ...

# %%
df.groupby('Gender')['Age'].value_counts(bins = 10).sort_index()
# Out:
# <ipython-input-107-c4b565962c8a>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Age'].value_counts(bins = 10).sort_index()
# Gender  Age
# Female  (17.956999999999997, 22.2]     25
#         (22.2, 26.4]                   32
#         (26.4, 30.6]                   89
#         (30.6, 34.8]                  108
#         (34.8, 39.0]                  117
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (47.4, 51.6]                   35
#         (51.6, 55.8]                   36
#         (55.8, 60.0]                   21
# Male    (17.956999999999997, 22.2]     32
#         (22.2, 26.4]                   73
#         (26.4, 30.6]                  135
#         (30.6, 34.8]                  157
# ...

# %%
df.groupby('Gender')['Age'].value_counts(bins = 10, normalize = True).mul(100).round(1).sort_index()
# Out:
# <ipython-input-108-7034ca36df1d>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Age'].value_counts(bins = 10, normalize = True).mul(100).round(1).sort_index()
# Gender  Age
# Female  (17.956999999999997, 22.2]     4.3
#         (22.2, 26.4]                   5.4
#         (26.4, 30.6]                  15.1
#         (30.6, 34.8]                  18.4
#         (34.8, 39.0]                  19.9
#         (39.0, 43.2]                  11.7
#         (43.2, 47.4]                   9.5
#         (47.4, 51.6]                   6.0
#         (51.6, 55.8]                   6.1
#         (55.8, 60.0]                   3.6
# Male    (17.956999999999997, 22.2]     3.6
#         (22.2, 26.4]                   8.3
#         (26.4, 30.6]                  15.3
# ...

# %% [markdown]
# OBS: histogramas -> valores contínuos; gráfico de barras -> variáveis categóricas

# %%
df.groupby('Gender')['Age'].plot(kind = 'hist', legend = True, alpha = 0.5)
# Out:
# <ipython-input-109-379f917eae81>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Age'].plot(kind = 'hist', legend = True, alpha = 0.5)
# Gender
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
df.hist(column = 'Age', by = 'Gender')
# Out:
# <ipython-input-110-96a6f4b9ca3c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist(column = 'Age', by = 'Gender')
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.hist(column = 'Age', by = 'Gender', sharey = True)
# Out:
# <ipython-input-111-e2a80a5b518e>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist(column = 'Age', by = 'Gender', sharey = True)
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.hist(column = 'Age', by = 'Gender', layout=(2,1), sharex=True)
# Out:
# <ipython-input-112-49304bcbeced>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist(column = 'Age', by = 'Gender', layout=(2,1), sharex=True)
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.hist(column = 'Age', by = 'Gender', layout=(2,1), sharex=True, figsize=(5, 7))
# Out:
# <ipython-input-113-ce20f0af060e>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist(column = 'Age', by = 'Gender', layout=(2,1), sharex=True, figsize=(5, 7))
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.groupby('Attrition')['Age'].size()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: Age, dtype: int64

# %%
df.groupby('Attrition')['Age'].mean()
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
df.groupby('Attrition')['Age'].value_counts()
# Out:
# Attrition  Age
# No         34     68
#            35     68
#            36     63
#            38     56
#            40     52
#                   ..
# Yes        45      2
#            48      2
#            49      2
#            51      2
#            53      2
# Name: count, Length: 82, dtype: int64

# %%
df.groupby('Attrition')['Age'].value_counts(bins = 10, normalize = True).mul(100).round(1).sort_index()
# Out:
# Attrition  Age
# No         (17.956999999999997, 22.2]     2.4
#            (22.2, 26.4]                   6.2
#            (26.4, 30.6]                  14.6
#            (30.6, 34.8]                  17.4
#            (34.8, 39.0]                  21.7
#            (39.0, 43.2]                  13.0
#            (43.2, 47.4]                   9.4
#            (47.4, 51.6]                   6.6
#            (51.6, 55.8]                   5.6
#            (55.8, 60.0]                   3.2
# Yes        (17.959, 22.0]                11.4
#            (22.0, 26.0]                  12.2
#            (26.0, 30.0]                  18.6
#            (30.0, 34.0]                  21.1
#            (34.0, 38.0]                  10.1
#            (38.0, 42.0]                   8.0
#            (42.0, 46.0]                   5.9
#            (46.0, 50.0]                   5.1
#            (50.0, 54.0]                   3.0
#            (54.0, 58.0]                   4.6
# ...

# %%
df.hist(column = 'Age', by = 'Attrition')
# Out:
# array([<Axes: title={'center': 'No'}>, <Axes: title={'center': 'Yes'}>],
#       dtype=object)

# %%
#Entendendo a função "cut" no pandas

# %%
faixas = [0, 20, 30, 50, float('inf')] #"float('inf')" = ideia de infinito

# %%
rotulos = ['Adolescente', 'Jovem Adulto', 'Adulto médio', 'Adulto sênior']

# %%
df['FaixaEtária'] = pd.cut(df['Age'], bins = faixas, labels = rotulos)

# %%
df[['Age', 'FaixaEtária']].head(20)
# Out:
#     Age    FaixaEtária
# 0    41   Adulto médio
# 1    49   Adulto médio
# 2    37   Adulto médio
# 3    33   Adulto médio
# 4    27   Jovem Adulto
# 5    32   Adulto médio
# 6    59  Adulto sênior
# 7    30   Jovem Adulto
# 8    38   Adulto médio
# 9    36   Adulto médio
# 10   35   Adulto médio
# 11   29   Jovem Adulto
# 12   31   Adulto médio
# 13   34   Adulto médio
# 14   28   Jovem Adulto
# 15   29   Jovem Adulto
# 16   32   Adulto médio
# 17   22   Jovem Adulto
# 18   53  Adulto sênior
# 19   38   Adulto médio

# %%
df[['Age', 'FaixaEtária']].tail(20)
# Out:
#       Age   FaixaEtária
# 1450   35  Adulto médio
# 1451   38  Adulto médio
# 1452   50  Adulto médio
# 1453   36  Adulto médio
# 1454   45  Adulto médio
# 1455   40  Adulto médio
# 1456   35  Adulto médio
# 1457   40  Adulto médio
# 1458   35  Adulto médio
# 1459   29  Jovem Adulto
# 1460   29  Jovem Adulto
# 1461   50  Adulto médio
# 1462   39  Adulto médio
# 1463   31  Adulto médio
# 1464   26  Jovem Adulto
# 1465   36  Adulto médio
# 1466   39  Adulto médio
# 1467   27  Jovem Adulto
# 1468   49  Adulto médio
# 1469   34  Adulto médio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
df['FaixaEtária'].value_counts()
# Out:
# FaixaEtária
# Adulto médio     941
# Jovem Adulto     358
# Adulto sênior    143
# Adolescente       28
# Name: count, dtype: int64

# %%
df['FaixaEtária'].value_counts().sort_index() #por padrão, o cut faz dados categóricos ordenados
# Out:
# FaixaEtária
# Adolescente       28
# Jovem Adulto     358
# Adulto médio     941
# Adulto sênior    143
# Name: count, dtype: int64

# %% [markdown]
# O "cut" é uma forma de criar categorias ordenadas sem usar valores numéricos

# %%
df['FaixaEtária'].value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: xlabel='FaixaEtária'>

# %%
pd.crosstab(
    df['FaixaEtária'],
    df['Attrition'],
    normalize = 'index'
).mul(100).round(1).style.background_gradient(cmap = 'RdYlGn', axis = 1)
# Out:
# <style type="text/css">
# #T_9659a_row0_col0, #T_9659a_row1_col1, #T_9659a_row2_col1, #T_9659a_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9659a_row0_col1, #T_9659a_row1_col0, #T_9659a_row2_col0, #T_9659a_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9659a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_9659a_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_9659a_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FaixaEtária</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9659a_level0_row0" class="row_heading level0 row0" >Adolescente</th>
#       <td id="T_9659a_row0_col0" class="data row0 col0" >42.900000</td>
# ...

# %%
colunas_categoricas_ordenadas.append('FaixaEtária')

# %%
colunas_categoricas_ordenadas
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'WorkLifeBalance',
#  'FaixaEtária']

# %%
df[colunas_numericas].hist();

# %%
df[colunas_numericas].hist(figsize = (15,10));

# %%
df['DistanceFromHome'].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column = 'DistanceFromHome', vert = False, showmeans = True);

# %%
df['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
df.groupby(['Gender', 'Attrition'])['Age'].describe()
# Out:
# <ipython-input-141-b8cb8c465f00>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Gender', 'Attrition'])['Age'].describe()
#                   count       mean       std   min   25%   50%    75%   max
# Gender Attrition
# Female No         501.0  38.155689  9.001762  18.0  31.0  37.0  45.00  60.0
#        Yes         87.0  32.574713  9.385333  18.0  27.0  31.0  36.50  58.0
# Male   No         732.0  37.154372  8.792917  18.0  31.0  36.0  43.00  60.0
#        Yes        150.0  34.206667  9.842584  18.0  28.0  32.0  39.75  58.0

# %%
df.boxplot(column = 'Age', by = ['Gender', 'Attrition'], showmeans=True);

# %%
df.groupby('JobLevel')['Age'].describe()
# Out:
#           count       mean       std   min   25%   50%   75%   max
# JobLevel
# 1         543.0  32.524862  8.463882  18.0  27.0  31.0  37.0  59.0
# 2         534.0  36.599251  7.503875  22.0  31.0  35.5  41.0  60.0
# 3         218.0  40.087156  8.114771  27.0  34.0  38.0  46.0  60.0
# 4         106.0  47.537736  6.485404  29.0  43.0  48.0  53.0  59.0
# 5          69.0  47.753623  5.778779  39.0  42.0  48.0  52.0  60.0

# %%
df.boxplot(column = 'Age', by = 'JobLevel', showmeans=True);

# %%
df.groupby(['Gender', 'Attrition'])['JobSatisfaction'].describe()
# Out:
# <ipython-input-146-5f21d31abb68>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Gender', 'Attrition'])['JobSatisfaction'].describe()
#                   count      mean       std  min  25%  50%  75%  max
# Gender Attrition
# Female No         501.0  2.728543  1.098255  1.0  2.0  3.0  4.0  4.0
#        Yes         87.0  2.425287  1.052485  1.0  2.0  2.0  3.0  4.0
# Male   No         732.0  2.812842  1.089283  1.0  2.0  3.0  4.0  4.0
#        Yes        150.0  2.493333  1.157100  1.0  1.0  3.0  3.0  4.0

# %%
df.boxplot(column = 'JobSatisfaction', by = ['Gender', 'Attrition'], showmeans = True);

# %%
df.groupby(['JobRole', 'Gender', 'JobLevel'])['MonthlyIncome'].describe()
# Out:
# <ipython-input-148-41057de23e1a>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'Gender', 'JobLevel'])['MonthlyIncome'].describe()
#                                            count          mean          std  \
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          31.0   5882.838710  1601.010475
#                                  3          17.0   9123.058824  1305.181188
#                                  4           3.0  13888.000000   133.371661
#                           Male   2          47.0   5853.808511  1026.214204
#                                  3          27.0   9515.629630  1312.786735
#                                  4           6.0  12515.500000  1165.564885
# ...

# %%
job_roles = df['JobRole'].unique()

job_roles
# Out:
# ['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources']
# Categories (9, object): ['Healthcare Representative', 'Human Resources', 'Laboratory Technician', 'Manager', ...,
#                          'Research Director', 'Research Scientist', 'Sales Executive',
#                          'Sales Representative']

# %%
for job in job_roles:
  df[df['JobRole'] == job].boxplot(column = 'MonthlyIncome', by = ['JobLevel', 'Gender'], showmeans = True);

# %%
for job in job_roles:
  df[df['JobRole'] == job].plot(kind = 'box', column = 'MonthlyIncome', by = ['JobLevel', 'Gender'], showmeans = True, title = job);
# Out:
# <ipython-input-153-633543e92f1e>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['JobRole'] == job].plot(kind = 'box', column = 'MonthlyIncome', by = ['JobLevel', 'Gender'], showmeans = True, title = job);
# <ipython-input-153-633543e92f1e>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['JobRole'] == job].plot(kind = 'box', column = 'MonthlyIncome', by = ['JobLevel', 'Gender'], showmeans = True, title = job);
# ...
